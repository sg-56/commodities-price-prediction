# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from feature_engine.creation import CyclicalFeatures
from feature_engine.encoding import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import pickle

# %%
data = pd.read_csv('Dataset.csv',index_col='date',parse_dates=True)
data.head()
# Out:
#                market         commodity    price  \
# date
# 2024-05-20  Wholesale              Rice   53.562
# 2024-05-20  Wholesale  Vanaspati Packed  106.828
# 2024-05-20  Wholesale          Gram Dal   80.650
# 2024-05-20  Wholesale     Tur Arhar Dal  151.984
# 2024-05-20  Wholesale          Urad Dal  127.156
#
#                                           unit
# date
# 2024-05-20         price in rupees per quintal
# 2024-05-20  price in rupees per hundred litres
# 2024-05-20         price in rupees per quintal
# 2024-05-20         price in rupees per quintal
# 2024-05-20         price in rupees per quintal

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 127248 entries, 2024-05-20 to 2014-01-02
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   market     127248 non-null  object
#  1   commodity  127248 non-null  object
#  2   price      126079 non-null  float64
#  3   unit       127248 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 4.9+ MB

# %%
#Removing unit column and assigning unit measurements for each category of Commodity
data.groupby(by=['commodity','unit'])['price'].mean()
# Out:
# commodity             unit
# Atta Wheat            price in rupees per kilogram           37.356470
#                       price in rupees per quintal            30.809908
# Gram Dal              price in rupees per kilogram           78.108603
#                       price in rupees per quintal            69.372876
# Groundnut Oil Packed  price in rupees per hundred litres    137.424513
#                       price in rupees per litre             149.233083
# Gur                   price in rupees per kilogram           49.198762
#                       price in rupees per quintal            42.117251
# Masoor Dal            price in rupees per kilogram           90.268071
#                       price in rupees per quintal            78.209935
# Milk                  price in rupees per hundred litres     37.510172
#                       price in rupees per litre              39.608280
# Moong Dal             price in rupees per kilogram          100.474466
#                       price in rupees per quintal            91.325462
# Mustard Oil Packed    price in rupees per hundred litres    137.084369
#                       price in rupees per litre             150.266942
# Onion                 price in rupees per kilogram           27.965372
#                       price in rupees per quintal            22.822288
# Palm Oil Packed       price in rupees per hundred litres     84.917240
#                       price in rupees per litre              90.434957
# Potato                price in rupees per kilogram           26.667711
#                       price in rupees per quintal            21.362807
# Rice                  price in rupees per kilogram           44.158562
#                       price in rupees per quintal            39.659475
# Salt Pack Iodised     price in rupees per kilogram           14.632925
#                       price in rupees per quintal            10.368764
# Soya Oil Packed       price in rupees per hundred litres     99.960234
#                       price in rupees per litre             109.271076
# Sugar                 price in rupees per kilogram           37.886671
#                       price in rupees per quintal            35.044737
# Sunflower Oil Packed  price in rupees per hundred litres    107.979137
#                       price in rupees per litre             113.734836
# Tea Loose             price in rupees per kilogram          268.955366
#                       price in rupees per quintal           228.610193
# Tomato                price in rupees per kilogram           24.823993
#                       price in rupees per quintal            19.849207
# Tur Arhar Dal         price in rupees per kilogram          107.844183
#                       price in rupees per quintal            99.373025
# Urad Dal              price in rupees per kilogram          114.756106
#                       price in rupees per quintal           105.346614
# Vanaspati Packed      price in rupees per hundred litres     88.739469
#                       price in rupees per litre             100.382884
# Wheat                 price in rupees per kilogram           34.335814
#                       price in rupees per quintal            30.373408
# Name: price, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 127248 entries, 2024-05-20 to 2014-01-02
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   market     127248 non-null  object
#  1   commodity  127248 non-null  object
#  2   price      126079 non-null  float64
#  3   unit       127248 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 4.9+ MB

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(data)

# %%
df
# Out:
#                market         commodity    price  \
# date
# 2024-05-20  Wholesale              Rice   53.562
# 2024-05-20  Wholesale  Vanaspati Packed  106.828
# 2024-05-20  Wholesale          Gram Dal   80.650
# 2024-05-20  Wholesale     Tur Arhar Dal  151.984
# 2024-05-20  Wholesale          Urad Dal  127.156
# ...               ...               ...      ...
# 2014-01-02  Wholesale   Soya Oil Packed   73.500
# 2014-01-02     Retail  Vanaspati Packed   67.500
# 2014-01-02  Wholesale  Vanaspati Packed   66.000
# 2014-01-02  Wholesale              Rice   27.750
# 2014-01-02     Retail            Tomato   12.000
#
#                                           unit  dayofweek  quarter  month  \
# date
# 2024-05-20         price in rupees per quintal          0        2      5
# 2024-05-20  price in rupees per hundred litres          0        2      5
# 2024-05-20         price in rupees per quintal          0        2      5
# 2024-05-20         price in rupees per quintal          0        2      5
# 2024-05-20         price in rupees per quintal          0        2      5
# ...                                        ...        ...      ...    ...
# 2014-01-02  price in rupees per hundred litres          3        1      1
# 2014-01-02           price in rupees per litre          3        1      1
# 2014-01-02  price in rupees per hundred litres          3        1      1
# 2014-01-02         price in rupees per quintal          3        1      1
# 2014-01-02        price in rupees per kilogram          3        1      1
#
#             year  dayofyear  dayofmonth  weekofyear
# date
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21
# ...          ...        ...         ...         ...
# 2014-01-02  2014          2           2           1
# 2014-01-02  2014          2           2           1
# 2014-01-02  2014          2           2           1
# 2014-01-02  2014          2           2           1
# 2014-01-02  2014          2           2           1
#
# [127248 rows x 11 columns]

# %%
#Getting Units for each commodity
Units = pd.DataFrame(df[df['market'] == 'Retail'].groupby(by=['commodity','unit'])['price'].agg('mean'))
Units.drop(columns=['price'],inplace = True)

Units = dict(Units.index)
df.drop(columns=['unit'],inplace = True)
df.head()
# Out:
#                market         commodity    price  dayofweek  quarter  month  \
# date
# 2024-05-20  Wholesale              Rice   53.562          0        2      5
# 2024-05-20  Wholesale  Vanaspati Packed  106.828          0        2      5
# 2024-05-20  Wholesale          Gram Dal   80.650          0        2      5
# 2024-05-20  Wholesale     Tur Arhar Dal  151.984          0        2      5
# 2024-05-20  Wholesale          Urad Dal  127.156          0        2      5
#
#             year  dayofyear  dayofmonth  weekofyear
# date
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21
# 2024-05-20  2024        141          20          21

# %%
imputer = KNNImputer(n_neighbors= 5)
df ['price'] = imputer.fit_transform(df[['price']])

# %%
df.isna().sum()
# Out:
# market        0
# commodity     0
# price         0
# dayofweek     0
# quarter       0
# month         0
# year          0
# dayofyear     0
# dayofmonth    0
# weekofyear    0
# dtype: int64

# %%
#Encoding Cyclic Features i.e (Day,Month,dayofweek,dayofmonth,dayofyear,dayofmonth)
cyclic_features = ['dayofweek','quarter','month','dayofyear','dayofmonth','weekofyear']
cat_feature = ['market','commodity']
cyclic_encoder = CyclicalFeatures(variables=cyclic_features,drop_original=True)
cat_encoder = OneHotEncoder(variables = cat_feature)
preprocessor = Pipeline(steps=[
    ('Cyclic_features',cyclic_encoder),
    ('cat_encoder',cat_encoder)
])
# Out:
# Pipeline(steps=[('Cyclic_features',
#                  CyclicalFeatures(drop_original=True,
#                                   variables=['dayofweek', 'quarter', 'month',
#                                              'dayofyear', 'dayofmonth',
#                                              'weekofyear'])),
#                 ('cat_encoder',
#                  OneHotEncoder(variables=['market', 'commodity']))])

# %%
df.index.max()
# Out:
# Timestamp('2024-05-20 00:00:00')

# %%
split_date = '2024-03-01'
df_train = df.loc[df.index < split_date].copy()
df_test = df.loc[df.index >= split_date].copy()

# %%
train_cols = df.drop(columns=['price']).columns
test_col = ['price']
print("Train Columns : ",train_cols)
print("Test Columns : ",test_col)
# Out:
# Train Columns :  Index(['market', 'commodity', 'dayofweek', 'quarter', 'month', 'year',
#        'dayofyear', 'dayofmonth', 'weekofyear'],
#       dtype='object')
# Test Columns :  ['price']

# %%
preprocessor.fit(df_train[train_cols])
# Out:
# Pipeline(steps=[('Cyclic_features',
#                  CyclicalFeatures(drop_original=True,
#                                   variables=['dayofweek', 'quarter', 'month',
#                                              'dayofyear', 'dayofmonth',
#                                              'weekofyear'])),
#                 ('cat_encoder',
#                  OneHotEncoder(variables=['market', 'commodity']))])

# %%
X_train = preprocessor.transform(df_train[train_cols])
X_test = preprocessor.transform(df_test[train_cols])

# %%
df_test[train_cols]
# Out:
#                market         commodity  dayofweek  quarter  month  year  \
# date
# 2024-05-20  Wholesale              Rice          0        2      5  2024
# 2024-05-20  Wholesale  Vanaspati Packed          0        2      5  2024
# 2024-05-20  Wholesale          Gram Dal          0        2      5  2024
# 2024-05-20  Wholesale     Tur Arhar Dal          0        2      5  2024
# 2024-05-20  Wholesale          Urad Dal          0        2      5  2024
# ...               ...               ...        ...      ...    ...   ...
# 2024-03-01     Retail             Sugar          4        1      3  2024
# 2024-03-01  Wholesale             Wheat          4        1      3  2024
# 2024-03-01     Retail        Masoor Dal          4        1      3  2024
# 2024-03-01  Wholesale        Masoor Dal          4        1      3  2024
# 2024-03-01  Wholesale             Sugar          4        1      3  2024
#
#             dayofyear  dayofmonth  weekofyear
# date
# 2024-05-20        141          20          21
# 2024-05-20        141          20          21
# 2024-05-20        141          20          21
# 2024-05-20        141          20          21
# 2024-05-20        141          20          21
# ...               ...         ...         ...
# 2024-03-01         61           1           9
# 2024-03-01         61           1           9
# 2024-03-01         61           1           9
# 2024-03-01         61           1           9
# 2024-03-01         61           1           9
#
# [3476 rows x 9 columns]

# %%
from xgboost import XGBRegressor
xg = XGBRegressor(device="cuda",eval_metric = 'rmse',n_estimators = 500)
xg.fit(X_train,df_train[test_col],verbose = 2)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
train_predicts = xg.predict(X_train)
test_predicts = xg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(df_train[test_col],train_predicts))
print(mean_squared_error(df_test[test_col],test_predicts))
# Out:
# 6.183085202058439
# 12.058731842928411

# %%
data = {'Feature_names':xg.feature_names_in_,'Importance':xg.feature_importances_}

# %%
pd.DataFrame(data)
# Out:
#                      Feature_names  Importance
# 0                             year    0.004361
# 1                    dayofweek_sin    0.000075
# 2                    dayofweek_cos    0.000062
# 3                      quarter_sin    0.000666
# 4                      quarter_cos    0.000909
# 5                        month_sin    0.000464
# 6                        month_cos    0.000638
# 7                    dayofyear_sin    0.000273
# 8                    dayofyear_cos    0.000218
# 9                   dayofmonth_sin    0.000041
# 10                  dayofmonth_cos    0.000048
# 11                  weekofyear_sin    0.000232
# 12                  weekofyear_cos    0.000191
# 13                market_Wholesale    0.001725
# 14                   market_Retail    0.000000
# 15                 commodity_Wheat    0.122221
# 16            commodity_Masoor Dal    0.003771
# 17  commodity_Groundnut Oil Packed    0.063556
# 18       commodity_Soya Oil Packed    0.022927
# 19  commodity_Sunflower Oil Packed    0.040137
# 20                  commodity_Milk    0.025331
# 21      commodity_Vanaspati Packed    0.012097
# 22                  commodity_Rice    0.045433
# 23              commodity_Urad Dal    0.022502
# 24    commodity_Mustard Oil Packed    0.045249
# 25       commodity_Palm Oil Packed    0.009074
# 26                 commodity_Onion    0.019049
# 27         commodity_Tur Arhar Dal    0.018012
# 28             commodity_Tea Loose    0.102869
# 29                   commodity_Gur    0.035915
# 30            commodity_Atta Wheat    0.063504
# 31             commodity_Moong Dal    0.026458
# 32              commodity_Gram Dal    0.001880
# 33                commodity_Potato    0.054714
# 34                 commodity_Sugar    0.073700
# 35                commodity_Tomato    0.016879
# 36     commodity_Salt Pack Iodised    0.164818

# %%
with open('Preprocessor.pkl',mode = 'wb') as file:
    pickle.dump(preprocessor,file)

# %%
with open('Preprocessor.pkl',mode = 'rb') as file:
    pre = pickle.load(file)

# %%
pre.feature_names_in_
# Out:
# ['market',
#  'commodity',
#  'dayofweek',
#  'quarter',
#  'month',
#  'year',
#  'dayofyear',
#  'dayofmonth',
#  'weekofyear']

# %%
with open('Model.pkl',mode = 'wb') as file:
    pickle.dump(xg,file)

# %%
xg
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
